# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.special import ellipeinc
from scipy.special import ellipkinc

# %% [markdown]
# # ESFEROIDES

# %%
#Definimos variables

e=np.linspace(10**-4,1,10000)

#n=0
#kn=1

#n=0.1
#kn=0.96064

#n=0.5
#kn=0.81482

n=1
kn=0.65345

#n=1.5
#kn=0.51149

#n=2
#kn=0.38712

#n=2.5
#kn=0.27951

#n=2.7
#kn=0.24109

Omegagorro2= 2*((1-e**2)**(1/2)/(e**3) * (3-2*e**2)*np.arcsin(e) - (3*(1-e**2))/(e**2))
Jgorro2=(3/25) * (1-e**2)**(-2/3) * Omegagorro2
g=(np.arcsin(e))/e * (1 - e**2)**(1/6)
T_W=(3/(2* e**2))*(1- (e*(1 - e**2)**(1/2)/(np.arcsin(e)))) - 1

def CocienteRoR3(n,kn):   #
    g=(np.arcsin(e))/e * (1 - e**2)**(1/6)
    T_W=(3/(2* e**2))*(1- (e*(1 - e**2)**(1/2)/(np.arcsin(e)))) - 1
    CocienteRoR3=((g*(1 - (2*T_W)))**(3*n/(3-n))) + 0*kn
    return CocienteRoR3

def Omegabarra2(n,kn):
    Omegabarra2=CocienteRoR3(n,kn) * ((1/(kn*(1-n/5))) * Omegagorro2)
    return Omegabarra2

def Jbarra2(n,kn):
    Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
    return Jbarra2

def Jbarra(n,kn):
    Jbarra=Jbarra2(n,kn)**(1/2)
    return Jbarra

def Ebarra(n,kn):
    g=(np.arcsin(e))/e * (1 - e**2)**(1/6)
    T_W=(3/(2* e**2))*(1- (e*(1 - e**2)**(1/2)/(np.arcsin(e)))) - 1
    Ebarra=CocienteRoR3(n,kn)**(1/3) * ((3-n)/(3)) * (-3/(5-n)) * g *(1 - ((3-2*n)/(3-n))*(T_W))
    return Ebarra
# Out:
# <ipython-input-2-77b7ce5622a8>:30: RuntimeWarning: divide by zero encountered in power
#   Jgorro2=(3/25) * (1-e**2)**(-2/3) * Omegagorro2
# <ipython-input-2-77b7ce5622a8>:30: RuntimeWarning: invalid value encountered in multiply
#   Jgorro2=(3/25) * (1-e**2)**(-2/3) * Omegagorro2

# %%
n=1
kn=0.65345
max_index = np.argmax(Omegabarra2(n,kn))
Jbarra(n,kn)[max_index]
# Out:
# <ipython-input-2-77b7ce5622a8>:45: RuntimeWarning: divide by zero encountered in power
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# <ipython-input-2-77b7ce5622a8>:45: RuntimeWarning: invalid value encountered in multiply
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# np.float64(0.2859938362106884)

# %%
plt.figure(figsize=(18, 36))

# Subplot 1
plt.subplot(6, 2, 1)
plt.plot(e,Omegabarra2(0,1), 'r-', label='n=0')
plt.plot(e,Omegabarra2(1,0.65345), 'g-', label='n=1')
plt.plot(e,Omegabarra2(1.5,0.51149), 'b-', label='n=1.5')
#plt.plot(e,Omegabarra2(2,0.38712), 'r--', label='n=2')
plt.plot(e,Omegabarra2(2.5,0.27951), 'g--', label='n=2.5')
plt.xlabel('parámetro adimensional e', fontsize=15)
plt.ylabel('$\overline{\Omega}^{2}$', fontsize=15)
plt.legend(fontsize=15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.grid()

# Subplot 2
plt.subplot(6, 2, 2)
plt.plot(Jbarra(0,1),Omegabarra2(0,1), 'r-', label='n=0')
plt.plot(Jbarra(1,0.65345),Omegabarra2(1,0.65345), 'g-', label='n=1')
plt.plot(Jbarra(1.5,0.51149),Omegabarra2(1.5,0.51149), 'b-', label='n=1.5')
#plt.plot(Jbarra(2,0.38712),Omegabarra2(2,0.38712), 'r--', label='n=2')
plt.plot(Jbarra(2.5,0.27951),Omegabarra2(2.5,0.27951), 'g--', label='n=2.5')
plt.xlabel('$\overline{J}$', fontsize=15)
plt.ylabel('$\overline{\Omega}^{2}$', fontsize=15)
plt.legend(fontsize=15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.grid()
plt.xlim(0, 1.5)  # Ajuste del límite del eje x

# Subplot 3
plt.subplot(6, 2, 3)
plt.plot(e,Omegagorro2, color='black', label='Independiente de n')
plt.xlabel('parámetro adimensional e', fontsize=15)
plt.ylabel('$\hat{\Omega}^2$', fontsize=15)
plt.legend(fontsize=15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.grid()

# Subplot 4
plt.subplot(6, 2, 4)
plt.plot(Jbarra(1,0.65345),Omegabarra2(1,0.65345), 'g-', label='n=1')
plt.xlabel('$\overline{J}$', fontsize=15)
plt.ylabel('$\overline{\Omega}^{2}$', fontsize=15)
plt.legend(fontsize=15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.grid()

# Subplot 5
plt.subplot(6, 2, 5)
plt.plot(e,Omegabarra2(0,1), 'r-', label='n=0')
plt.xlabel('parámetro adimensional e', fontsize=15)
plt.ylabel('$\overline{\Omega}^{2}$', fontsize=15)
plt.legend(fontsize=15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.grid()

# Subplot 6
plt.subplot(6, 2, 6)
plt.plot(Jbarra(0,1),Ebarra(0,1), 'r-', label='n=0')
plt.plot(Jbarra(1,0.65345),Ebarra(1,0.65345), 'g-', label='n=1')
plt.plot(Jbarra(1.5,0.51149),Ebarra(1.5,0.51149), 'b-', label='n=1.5')
#plt.plot(Jbarra(2,0.38712),Ebarra(2,0.38712), 'r--', label='n=2')
plt.plot(Jbarra(2.5,0.27951),Ebarra(2.5,0.27951), 'g--', label='n=2.5')
plt.xlabel('$\overline{J}$', fontsize=15)
plt.ylabel('$\overline{E}$', fontsize=15)
plt.legend(fontsize=15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.grid()
plt.xlim(0, 1.5)  # Ajuste del límite del eje x
# Out:
# <ipython-input-2-77b7ce5622a8>:45: RuntimeWarning: divide by zero encountered in power
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# <ipython-input-2-77b7ce5622a8>:45: RuntimeWarning: invalid value encountered in multiply
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# (0.0, 1.5)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))

# Subplot 1 (anteriormente subplot 2)
plt.subplot(2, 1, 2)
plt.plot(Jbarra(0,1), Omegabarra2(0,1), 'r-', label='n=0')
plt.plot(Jbarra(1,0.65345), Omegabarra2(1,0.65345), 'g-', label='n=1')
plt.plot(Jbarra(1.5,0.51149), Omegabarra2(1.5,0.51149), 'b-', label='n=1.5')
#plt.plot(Jbarra(2,0.38712), Omegabarra2(2,0.38712), 'r--', label='n=2')
plt.plot(Jbarra(2.5,0.27951), Omegabarra2(2.5,0.27951),'-', color='orange', label='n=2.5')
plt.xlabel('$\overline{J}$', fontsize=23)
plt.ylabel('$\overline{\Omega}^{2}$', fontsize=23)
plt.legend(fontsize=17)
plt.xticks(size=19)
plt.yticks(size=19)
plt.grid()
plt.xlim(0, 1.3)

# Subplot 2 (anteriormente subplot 6)
plt.subplot(2, 1, 1)
plt.plot(Jbarra(0,1), Ebarra(0,1), 'r-', label='n=0')
plt.plot(Jbarra(1,0.65345), Ebarra(1,0.65345), 'g-', label='n=1')
plt.plot(Jbarra(1.5,0.51149), Ebarra(1.5,0.51149), 'b-', label='n=1.5')
#plt.plot(Jbarra(2,0.38712), Ebarra(2,0.38712), 'r--', label='n=2')
plt.plot(Jbarra(2.5,0.27951), Ebarra(2.5,0.27951), '-', color='orange', label='n=2.5')
plt.xlabel('$\overline{J}$', fontsize=23)
plt.ylabel('$\overline{E}$', fontsize=23)
plt.legend(fontsize=17)
plt.xticks(size=19)
plt.yticks(size=19)
plt.grid()
plt.xlim(0, 1.3)

plt.tight_layout()

plt.savefig('R1.pdf', format='pdf')

plt.show()
# Out:
# <ipython-input-2-77b7ce5622a8>:45: RuntimeWarning: divide by zero encountered in power
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# <ipython-input-2-77b7ce5622a8>:45: RuntimeWarning: invalid value encountered in multiply
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))

# %%
plt.figure(figsize=(12, 8))
plt.plot(e,Omegabarra2(0,1), 'r-', label='n=0')
plt.plot(e,Omegabarra2(1,0.65345), 'g-', label='n=1')
plt.plot(e,Omegabarra2(1.5,0.51149), 'b-', label='n=1.5')
#plt.plot(e,Omegabarra2(2,0.38712), 'r--', label='n=2')
plt.plot(e,Omegabarra2(2.5,0.27951), '-', color='orange', label='n=2.5')
plt.xlabel(r'$e$', fontsize=23)
plt.ylabel('$\overline{\Omega}^{2}$', fontsize=23)
plt.legend(fontsize=17)
plt.xticks(size = 19)
plt.yticks(size = 19)
plt.grid()
plt.tight_layout()

plt.savefig('R2.pdf', format='pdf')

plt.show()

# %%
## Por qué difiere el comportamiento al variar n? (resultado 1 y 2)
## El 3cer resultado coincide con Shapiro
## El 5to y 6to resultado coincide con chandrasekar, considerando mi justificacion (cuaderno)
## 4to resultado no coincide con Jose, hablar del 0.5

# %%
plt.plot(e,Omegabarra2(0,1), 'r-', label='n=0')
plt.plot(e,Omegabarra2(1,0.65345), 'g-', label='n=1')
plt.plot(e,Omegabarra2(1.5,0.51149), 'b-', label='n=1.5')
#plt.plot(e,Omegabarra2(2,0.38712), 'r--', label='n=2')
plt.plot(e,Omegabarra2(2.5,0.27951), 'g--', label='n=2.5')
plt.xlabel('parámetro adimensional e', fontsize=15)
plt.ylabel('$\overline{\Omega}^{2}$', fontsize=15)
plt.legend(fontsize=15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.grid()

# %%
plt.plot(Jbarra(0,1),Omegabarra2(0,1), 'r-', label='n=0')
plt.plot(Jbarra(1,0.65345),Omegabarra2(1,0.65345), 'g-', label='n=1')
plt.plot(Jbarra(1.5,0.51149),Omegabarra2(1.5,0.51149), 'b-', label='n=1.5')
#plt.plot(Jbarra(2,0.38712),Omegabarra2(2,0.38712), 'r--', label='n=2')
plt.plot(Jbarra(2.5,0.27951),Omegabarra2(2.5,0.27951), 'g--', label='n=2.5')
plt.xlabel('$\overline{J}$', fontsize=15)
plt.ylabel('$\overline{\Omega}^{2}$', fontsize=15)
plt.legend(fontsize=15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.grid()
plt.xlim(0, 1.5)  # Ajuste del límite del eje x
# Out:
# <ipython-input-2-77b7ce5622a8>:45: RuntimeWarning: divide by zero encountered in power
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# <ipython-input-2-77b7ce5622a8>:45: RuntimeWarning: invalid value encountered in multiply
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# (0.0, 1.5)

# %%
plt.plot(Jbarra(0,1),Ebarra(0,1), 'r-', label='n=0')
plt.plot(Jbarra(1,0.65345),Ebarra(1,0.65345), 'g-', label='n=1')
plt.plot(Jbarra(1.5,0.51149),Ebarra(1.5,0.51149), 'b-', label='n=1.5')
#plt.plot(Jbarra(2,0.38712),Ebarra(2,0.38712), 'r--', label='n=2')
plt.plot(Jbarra(2.5,0.27951),Ebarra(2.5,0.27951), '-', color='orange', label='n=2.5')
plt.xlabel('$\overline{J}$', fontsize=15)
plt.ylabel('$\overline{E}$', fontsize=15)
plt.legend(fontsize=15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.grid()
plt.xlim(0, 1.3)  # Ajuste del límite del eje x
# Out:
# <ipython-input-2-77b7ce5622a8>:45: RuntimeWarning: divide by zero encountered in power
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# <ipython-input-2-77b7ce5622a8>:45: RuntimeWarning: invalid value encountered in multiply
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# (0.0, 1.3)

# %% [markdown]
# # ELIPSOIDES de JACOBI

# %% [markdown]
# ## Integrales elípticas

# %%
import numpy as np
from scipy.optimize import least_squares
from scipy.special import ellipeinc, ellipkinc

def calcular_a3a1_con_rango_ajustado(a2a1):
    def ecuacion(a3a1):
        a3a2 = a3a1 / a2a1
        sin2theta = ((1 - (a2a1) ** 2) / (1 - (a3a1) ** 2))

        # Verifica si sin2theta está fuera de los límites de arcsin
        if np.any(sin2theta < 0) or np.any(sin2theta > 1):
            return np.inf  # Devolver un valor alto para no considerar esta solución

        sintheta = np.sqrt(sin2theta)
        phi = np.arccos(a3a1)

        E = ellipeinc(phi, sin2theta)
        F = ellipkinc(phi, sin2theta)

        # Verifica si phi, m o sin(theta) están fuera de rango
        if not np.isfinite(E).all() or not np.isfinite(F).all() or np.any(np.sin(phi) == 0):
            return np.inf  # Devolver un valor alto para no considerar esta solución

        A1 = 2 * a2a1 * a3a1 * (F - E) / ((np.sin(phi)) ** 3 * sin2theta)
        A2 = 2 * a2a1 * a3a1 * (E - F * (1 - sin2theta) - a3a2 * sin2theta * np.sin(phi)) / ((np.sin(phi)) ** 3 * sin2theta * (1 - sin2theta))
        A3 = 2 * a2a1 * a3a1 * ((a3a2 ** (-1)) * np.sin(phi) - E) / ((np.sin(phi)) ** 3 * (1 - sin2theta))

        # Asegúrate de que no haya divisiones por cero
        if np.any(np.isnan(A1)) or np.any(np.isnan(A2)) or np.any(np.isnan(A3)):
            return np.inf  # Devolver un valor alto para no considerar esta solución

        lhs = (A1 - A2)
        rhs = (a3a1 ** 2) * A3 * (1 - (a2a1 ** (-2)))

        # Verifica que lhs y rhs sean valores finitos
        if not np.isfinite(lhs).all() or not np.isfinite(rhs).all():
            return np.inf  # Devolver un valor alto para no considerar esta solución

        return lhs - rhs

    # Rango de valores iniciales para a3a1
    rango_inicial = [
        0.4944*(10**(-1)), 0.9682*(10**(-1)), 0.1416, 0.1835, 0.2228, 0.2594,
        0.2937, 0.3256, 0.3554, 0.3833, 0.4094, 0.4338, 0.4567, 0.4781,
        0.4983, 0.5172, 0.5351, 0.5519, 0.5677, 0.5828
    ]

    # Resolver para cada valor inicial y seleccionar el mejor resultado
    soluciones = []
    for a3a1_inicial in rango_inicial:
        try:
            solucion = least_squares(
                ecuacion,
                a3a1_inicial,
                bounds=(0, 1),
                xtol=1e-10,  # Tolerancia en el valor de la solución
                gtol=1e-10,  # Tolerancia en el gradiente
                ftol=1e-10   # Tolerancia en el valor de la función
            ).x[0]
            soluciones.append(solucion)
        except ValueError as e:
            print(f"Error en least_squares con valor inicial {a3a1_inicial}: {e}")

    if not soluciones:
        return np.nan  # Si no hay soluciones válidas, devuelve NaN

    # Seleccionar la solución que mejor satisfaga la ecuación
    errores = [np.abs(ecuacion(solucion)) for solucion in soluciones]
    mejor_solucion = soluciones[np.argmin(errores)]

    return mejor_solucion

# Valores de a2a1
a2a1 = np.linspace(0.05, 1, 40)

# Calcular a3a1 para cada valor de a2a1
a3a1_calculados_rango_ajustado = np.array([calcular_a3a1_con_rango_ajustado(a) for a in a2a1])

# Imprimir los resultados con más decimales
np.set_printoptions(precision=10)
print(a3a1_calculados_rango_ajustado)
# Out:
# Error en least_squares con valor inicial 0.09682: Residuals are not finite in the initial point.
# Error en least_squares con valor inicial 0.1416: Residuals are not finite in the initial point.
# Error en least_squares con valor inicial 0.1835: Residuals are not finite in the initial point.
# Error en least_squares con valor inicial 0.2228: Residuals are not finite in the initial point.
# Error en least_squares con valor inicial 0.2594: Residuals are not finite in the initial point.
# Error en least_squares con valor inicial 0.2937: Residuals are not finite in the initial point.
# Error en least_squares con valor inicial 0.3256: Residuals are not finite in the initial point.
# Error en least_squares con valor inicial 0.3554: Residuals are not finite in the initial point.
# Error en least_squares con valor inicial 0.3833: Residuals are not finite in the initial point.
# Error en least_squares con valor inicial 0.4094: Residuals are not finite in the initial point.
# ...

# %%
a3a1=a3a1_calculados_rango_ajustado
a3a1
# Out:
# array([0.0494435058, 0.0728320449, 0.0956324191, 0.117802893 ,
#        0.1393229669, 0.1601856875, 0.1803930824, 0.1999532567,
#        0.2188784588, 0.2371837468, 0.2548860459, 0.2720034706,
#        0.2885548295, 0.3045592618, 0.3200359685, 0.3350040135,
#        0.3494821776, 0.3634888521, 0.3770419621, 0.3901589136,
#        0.4028565581, 0.4151511705, 0.4270584384, 0.4385934588,
#        0.4497707415, 0.4606042168, 0.4711072472, 0.4812926414,
#        0.49117267  , 0.5007590834, 0.5100631294, 0.5190955718,
#        0.5278667097, 0.5363863958, 0.5446640552, 0.5527087037,
#        0.5605289658, 0.5681330917, 0.5755289744,          nan])

# %%
#n=0
#kn=1

#a2a1=np.linspace(0.05,1,20)
#a3a1=[0.4944*(10**(-1)), 0.9682*(10**(-1)), 0.1416, 0.1835, 0.2228, 0.2594, 0.2937, 0.3256, 0.3554, 0.3833, 0.4094, 0.4338, 0.4567, 0.4781, 0.4983, 0.5172, 0.5351, 0.5519, 0.5677, 0.5827]
a3a1=np.array(a3a1)
a3a2=a3a1/a2a1
sin2theta=((1-(a2a1)**2)/(1-(a3a1)**2))
sintheta=sin2theta**(1/2)
theta=np.arcsin(sintheta)
m=sin2theta
phi=np.arccos(a3a1)

# %%
E=ellipeinc(phi, m)
F=ellipkinc(phi,m)

A1=2*a2a1*a3a1*(F-E)/((np.sin(phi))**3 * m)
A2=2*a2a1*a3a1*(E - F*(1-m) - a3a2*m*np.sin(phi))/((np.sin(phi))**3 * m * (1-m))
A3=2*a2a1*a3a1*((a3a2**(-1))*np.sin(phi) - E)/((np.sin(phi))**3 * (1-m))

B12=A2 - ((A1-A2)/(a2a1**2 - 1))

# %%
TW=(A1 + A2*(a2a1**2) - 2*A3*(a3a1**2))/(2*(A1 + A2*(a2a1**2) + A3*(a3a1**2)))

#qn=kn*(1-(n/5))

#Omegamoño2=2*B12/qn

f=1/2 * (A1/(a2a1**(2/3) * a3a1**(2/3)) + A2/(a2a1**(-2/3) * a3a2**(2/3)) + A3/(a3a1**(-2/3) * a3a2**(-2/3)))
#_CocienteRoR3=((f*(1 - (2*TW)))**(3*n/(3-n)))

def _Omegamoño2(n,kn):
    qn=kn*(1-(n/5))
    _Omegamoño2=2*B12/qn
    return _Omegamoño2

def _CocienteRoR3(n,kn):
    _CocienteRoR3=((f*(1 - (2*TW)))**(3*n/(3-n))) + 0*kn
    return _CocienteRoR3

def _Omegabarra2(n,kn):
    _Omegabarra2=_CocienteRoR3(n,kn) * _Omegamoño2(n,kn)
    return _Omegabarra2

def _Jmoño(n,kn):
    _Jmoño=(np.sqrt(3) / 10) * kn * (_Omegamoño2(n,kn))**(1/2) * ((a2a1**(-2/3)) * (a3a1**(-2/3)) + (a2a1**(2/3)) * (a3a2**(-2/3)))
    return _Jmoño

def _Jbarra(n,kn):
    #_CocienteRoR3=((f*(1 - (2*TW)))**(3*n/(3-n))) + 0*kn
    _Jbarra=_Jmoño(n,kn) * _CocienteRoR3(n,kn)**(-1/6)
    return _Jbarra

def _Omegagorro2(n,kn):
    qn=kn*(1-(n/5))
    _Omegagorro2=qn * (_CocienteRoR3(n,kn))**(-1) * _Omegabarra2(n,kn)
    return _Omegagorro2

def _Jgorro2(n,kn):
    qn=kn*(1-(n/5))
    _Jgorro2=qn/(kn**2) * (_CocienteRoR3(n,kn))**(1/3) * (_Jbarra(n,kn))**2
    return _Jgorro2

def _Ebarra(n,kn):
    _Ebarra=-(3-n)/(5-n) * _CocienteRoR3(n,kn)**(1/3) * f * (1 -((3-2*n)/(3-n))*TW)
    return _Ebarra

# %%
n=1
kn=0.65345
#_Omegabarra2(n,kn)
#_Omegagorro2(n,kn)
#_Omegamoño2(n,kn)
#_CocienteRoR3(n,kn)**(-1/3)
_Omegabarra2(n,kn)
# Out:
# array([0.0037509115, 0.009926069 , 0.0192369662, 0.0314117668,
#        0.0460315599, 0.0626240533, 0.0807172876, 0.0998693658,
#        0.1196834768, 0.1398139239, 0.1599667612, 0.1798973308,
#        0.1994061518, 0.2183340743, 0.2365572551, 0.2539822884,
#        0.2705416715, 0.2861896981, 0.3008988086, 0.3146563934,
#        0.3274620248, 0.3393250821, 0.3502627291, 0.3602982052,
#        0.3694593887, 0.3777775979, 0.3852865956, 0.3920217681,
#        0.3980194533, 0.403316394 , 0.4079492975, 0.4119544851,
#        0.4153676149, 0.418223469 , 0.4205557907, 0.4223971659,
#        0.4237789389, 0.4247311577, 0.4252825433,          nan])

# %%
plt.figure(figsize=(18, 36))

n=2.5
kn=0.27951
# Subplot 1
plt.subplot(4, 2, 1)
plt.plot(_Jbarra(n,kn),_Omegabarra2(n,kn), color='black', linestyle=':', label='Elipsoides Jacobi')
plt.plot(Jbarra(n,kn),Omegabarra2(n,kn),  color='black', linestyle='-', label='Esferoides Maclaurin')
plt.text(1.2, 0.3, 'n=2.5', fontsize=20, color='black')
plt.xlabel('$\overline{J}$', fontsize=15)
plt.ylabel('$\overline{\Omega}^{2}$', fontsize=15)
plt.legend(fontsize=15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.grid()
plt.xlim(0, 1.5)  # Ajuste del límite del eje x
plt.ylim(0, 0.5)  # Ajuste del límite del eje y


n=1
kn=0.65345
# Subplot 2
plt.subplot(4, 2, 2)
plt.plot(_Jbarra(n,kn),_Omegabarra2(n,kn), color='black', linestyle=':', label='Elipsoides Jacobi')
plt.plot(Jbarra(n,kn),Omegabarra2(n,kn),  color='black', linestyle='-', label='Esferoides Maclaurin')
plt.text(1.2, 0.3, 'n=1', fontsize=20, color='black')
plt.xlabel('$\overline{J}$', fontsize=15)
plt.ylabel('$\overline{\Omega}^{2}$', fontsize=15)
plt.legend(fontsize=15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.grid()
plt.xlim(0, 1.5)  # Ajuste del límite del eje x
plt.ylim(0, 0.5)  # Ajuste del límite del eje y

n=0
kn=1
# Subplot 3
plt.subplot(4, 2, 3)
plt.plot(_Jbarra(n,kn),_Omegabarra2(n,kn), color='black', linestyle=':', label='Elipsoides Jacobi')
plt.plot(Jbarra(n,kn),Omegabarra2(n,kn),  color='black', linestyle='-', label='Esferoides Maclaurin')
plt.text(1.2, 0.3, 'n=0', fontsize=20, color='black')
plt.xlabel('$\overline{J}$', fontsize=15)
plt.ylabel('$\overline{\Omega}^2$', fontsize=15)
plt.legend(fontsize=15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.grid()
plt.xlim(0, 1.5)  # Ajuste del límite del eje x
plt.ylim(0, 0.5)  # Ajuste del límite del eje y


# Subplot 4
plt.subplot(4, 2, 4)
n=2.5
kn=0.27951
plt.plot(_Jbarra(n,kn),_Ebarra(n,kn), 'r:', label='n=2.5')
plt.plot(Jbarra(n,kn),Ebarra(n,kn), 'r-')
n=1
kn=0.65345
plt.plot(_Jbarra(n,kn),_Ebarra(n,kn), 'g:', label='n=1')
plt.plot(Jbarra(n,kn),Ebarra(n,kn), 'g-')
n=0
kn=1
plt.plot(_Jbarra(n,kn),_Ebarra(n,kn), 'b:', label='n=0')
plt.plot(Jbarra(n,kn),Ebarra(n,kn), 'b-')
plt.xlabel('$\overline{J}$', fontsize=15)
plt.ylabel('$\overline{E}$', fontsize=15)
plt.legend(fontsize=15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.grid()
plt.xlim(0, 1.5)  # Ajuste del límite del eje x
plt.ylim(-0.6, 0)  # Ajuste del límite del eje x
# Out:
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: divide by zero encountered in power
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: invalid value encountered in multiply
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: divide by zero encountered in power
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: invalid value encountered in multiply
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# ...

# %%
plt.figure(figsize=(12, 8))
n=2.5
kn=0.27951
plt.plot(_Jbarra(n,kn),_Ebarra(n,kn), 'r:', label='n=2.5')
plt.plot(Jbarra(n,kn),Ebarra(n,kn), 'r-')
n=1
kn=0.65345
plt.plot(_Jbarra(n,kn),_Ebarra(n,kn), 'g:', label='n=1')
plt.plot(Jbarra(n,kn),Ebarra(n,kn), 'g-')
n=0
kn=1
plt.plot(_Jbarra(n,kn),_Ebarra(n,kn), 'b:', label='n=0')
plt.plot(Jbarra(n,kn),Ebarra(n,kn), 'b-')
plt.xlabel('$\overline{J}$', fontsize=23)
plt.ylabel('$\overline{E}$', fontsize=23)
plt.legend(fontsize=18)
plt.xticks(size = 21)
plt.yticks(size = 21)
plt.grid()
plt.xlim(0, 1.5)  # Ajuste del límite del eje x
plt.ylim(-0.6, 0)  # Ajuste del límite del eje x

plt.tight_layout()

plt.savefig('R3.pdf', format='pdf')

plt.show()
# Out:
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: divide by zero encountered in power
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: invalid value encountered in multiply
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: divide by zero encountered in power
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: invalid value encountered in multiply
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# ...

# %%
plt.figure(figsize=(12,6))

n=2.5
kn=0.27951
plt.plot(_Jbarra(n,kn),_Ebarra(n,kn), 'r:', label='n=2.5')
plt.plot(Jbarra(n,kn),Ebarra(n,kn), 'r-')
n=1
kn=0.65345
plt.plot(_Jbarra(n,kn),_Ebarra(n,kn), 'g:', label='n=1')
plt.plot(Jbarra(n,kn),Ebarra(n,kn), 'g-')
n=0
kn=1
plt.plot(_Jbarra(n,kn),_Ebarra(n,kn), 'b:', label='n=0')
plt.plot(Jbarra(n,kn),Ebarra(n,kn), 'b-')
plt.xlabel('$\overline{J}$', fontsize=15)
plt.ylabel('$\overline{E}$', fontsize=15)
plt.legend(fontsize=15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.grid()
plt.xlim(0, 1.5)  # Ajuste del límite del eje x
plt.ylim(-0.6, 0)  # Ajuste del límite del eje x
# Out:
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: divide by zero encountered in power
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: invalid value encountered in multiply
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: divide by zero encountered in power
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: invalid value encountered in multiply
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# ...

# %%
import matplotlib.pyplot as plt

n = 2.5
kn = 0.27951

plt.figure(figsize=(10, 6))
plt.plot(_Jbarra(n, kn), _Omegabarra2(n, kn), color='black', linestyle=':', label='Elipsoides de Jacobi')
plt.plot(Jbarra(n, kn), Omegabarra2(n, kn), color='black', linestyle='-', label='Esferoides de Maclaurin')
plt.text(1.2, 0.2, 'n=2.5', fontsize=30, color='black')
plt.xlabel('$\overline{J}$', fontsize=28)
plt.ylabel('$\overline{\Omega}^{2}$', fontsize=28)
plt.legend(fontsize=22)
plt.xticks(size=25)
plt.yticks(size=25)
plt.grid()
plt.xlim(0, 1.5)
plt.ylim(0, 0.5)
plt.tight_layout()

plt.savefig('R4.pdf', format='pdf')

plt.show()
# Out:
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: divide by zero encountered in power
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: invalid value encountered in multiply
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))

# %%
import matplotlib.pyplot as plt

n = 1
kn = 0.65345

plt.figure(figsize=(10, 6))
plt.plot(_Jbarra(n, kn), _Omegabarra2(n, kn), color='black', linestyle=':', label='Elipsoides de Jacobi')
plt.plot(Jbarra(n, kn), Omegabarra2(n, kn), color='black', linestyle='-', label='Esferoides de Maclaurin')
plt.text(1.2, 0.2, 'n=1', fontsize=30, color='black')
plt.xlabel('$\overline{J}$', fontsize=28)
plt.ylabel('$\overline{\Omega}^{2}$', fontsize=28)
plt.legend(fontsize=22)
plt.xticks(size=25)
plt.yticks(size=25)
plt.grid()
plt.xlim(0, 1.5)
plt.ylim(0, 0.5)
plt.tight_layout()

plt.savefig('R5.pdf', format='pdf')

plt.show()
# Out:
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: divide by zero encountered in power
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: invalid value encountered in multiply
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))

# %%
import matplotlib.pyplot as plt

n = 0
kn = 1

plt.figure(figsize=(10, 6))
plt.plot(_Jbarra(n, kn), _Omegabarra2(n, kn), color='black', linestyle=':', label='Elipsoides de Jacobi')
plt.plot(Jbarra(n, kn), Omegabarra2(n, kn), color='black', linestyle='-', label='Esferoides de Maclaurin')
plt.text(1.2, 0.2, 'n=0', fontsize=30, color='black')
plt.xlabel('$\overline{J}$', fontsize=28)
plt.ylabel('$\overline{\Omega}^2$', fontsize=28)
plt.legend(fontsize=22,loc=1)
plt.xticks(size=25)
plt.yticks(size=25)
plt.grid()
plt.xlim(0, 1.5)
plt.ylim(0, 0.5)
plt.tight_layout()

plt.savefig('R6.pdf', format='pdf')

plt.show()
# Out:
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: divide by zero encountered in power
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))
# C:\Users\juandf\AppData\Local\Temp\ipykernel_12980\590487448.py:45: RuntimeWarning: invalid value encountered in multiply
#   Jbarra2= CocienteRoR3(n,kn)**(-1/3) * (3/25) * (1 - e**2)**(-2/3) * Omegagorro2 * kn *(1/(1-n/5))

# %% [markdown]
# # ELIPSOIDES de RIEMANN-S INCOMPRESIBLES (n=0)

# %% [markdown]
# ## Integrales elípticas

# %%
import numpy as np
from scipy.optimize import least_squares
from scipy.special import ellipeinc, ellipkinc

# Definición de parámetros
a2a1_vals = np.linspace(0.05, 1, 40)
Cbarra = 1.767

# Valores específicos de a3a1
a3a1_vals = np.array([
    0.4944*(10**(-1)), 0.9682*(10**(-1)), 0.1416, 0.1835, 0.2228, 0.2594,
    0.2937, 0.3256, 0.3554, 0.3833, 0.4094, 0.4338, 0.4567, 0.4781,
    0.4983, 0.5172, 0.5351, 0.5519, 0.5677, 0.5828
])

# Funciones A1, A2, A3
def calcular_A1_A2_A3(a2a1, a3a1):
    try:
        a3a2 = a3a1 / a2a1
        sin2theta = ((1 - (a2a1) ** 2) / (1 - (a3a1) ** 2))
        sintheta = np.sqrt(sin2theta)
        phi = np.arccos(a3a1)

        E = ellipeinc(phi, sin2theta)
        F = ellipkinc(phi, sin2theta)

        A1 = 2 * a2a1 * a3a1 * (F - E) / ((np.sin(phi)) ** 3 * sin2theta)
        A2 = 2 * a2a1 * a3a1 * (E - F * (1 - sin2theta) - a3a2 * sin2theta * np.sin(phi)) / ((np.sin(phi)) ** 3 * sin2theta * (1 - sin2theta))
        A3 = 2 * a2a1 * a3a1 * ((a3a2 ** (-1)) * np.sin(phi) - E) / ((np.sin(phi)) ** 3 * (1 - sin2theta))

        if not (np.isfinite(A1) and np.isfinite(A2) and np.isfinite(A3)):
            return np.array([np.nan, np.nan, np.nan])

        return np.array([A1, A2, A3])
    except Exception as e:
        return np.array([np.nan, np.nan, np.nan])

# Función para definir el sistema de ecuaciones
def sistema_ecuaciones(variables, a2a1, Cbarra):
    a3a1, Omegabarra, zetabarra = variables

    A1, A2, A3 = calcular_A1_A2_A3(a2a1, a3a1)

    if np.isnan(A1) or np.isnan(A2) or np.isnan(A3):
        return [1e10, 1e10, 1e10]

    B12 = A2 - ((A1 - A2) / (a2a1**2 - 1))

    if not np.isfinite(B12):
        return [1e10, 1e10, 1e10]

    eq1 = Omegabarra**2 + ((a2a1)**2)/(1 + (a2a1)**2) * zetabarra**2 - 2 * B12
    eq2 = (a2a1**2)/(1 + a2a1**2) * zetabarra * Omegabarra - (A1 - A2)/(1 - (a2a1**(-2))) + a3a1**2 * A3
    eq3 = Cbarra/np.pi - (a3a1**(-1/3)) * ((a3a1/a2a1)**(-1/3)) * (2 * Omegabarra + zetabarra)

    return [eq1, eq2, eq3]

# Resolver para cada valor de a2a1 usando least_squares
soluciones = []
for a2a1 in a2a1_vals:
    for a3a1 in a3a1_vals:
        rango_inicial = [
            [a3a1, 0.15, -0.05], [a3a1, 0.4, 0.1], [a3a1, 0.1, -0.2], [a3a1, 0.6, 0.0], [a3a1, 0.3, -0.1]
        ]

        for x0 in rango_inicial:
            solucion = least_squares(sistema_ecuaciones, x0, bounds=([0, 0, -0.4], [1, 0.8, 0.2]), args=(a2a1, Cbarra), xtol=1e-12, gtol=1e-12, ftol=1e-12)

            if solucion.success:
                soluciones.append(solucion.x)
                break

# Resultados
soluciones = np.array(soluciones)
np.set_printoptions(precision=10)
print(soluciones)

# %%
import matplotlib.pyplot as plt
plt.plot(a2a1_vals,soluciones[:,1])

# %%
soluciones
